# %%
import matplotlib.pyplot as plt
import numpy as np
import sympy as sp
import math

# %% [markdown]
# ### Домашні завдання на відпрацювання поняття функції та її похідної
#
# 1. Задана функція залежності оцінки від кількості годин, витрачених на навчання: $ f(x) = 10x - 5 $.
#   1. З допомогою Python обчисліть похідну цієї функції.
#   2. Використовуйте бібліотеку `matplotlib` для побудови графіків функції та її похідної в діапазоні значень від 0 до 10 годин. Проаналізуйте, як зміна кількості годин вивчення впливає на оцінку.

# %%
# Функція 𝑓(𝑥)=10𝑥−5
def f(x):
  return 10 * x - 5

# %%
x = np.linspace(0, 10, 10)

# %%
# Похідна f'(x) = 2x
df = 2 * x

# %%
# Створення графіку
plt.figure(figsize=(15, 5))
plt.plot(x, f(x), label='f(x)=10x−5', color='blue')
plt.plot(x, df, label="f'(x)=2x", color='orange')

# Додавання легенди, міток та заголовка
plt.title("Графік функції та її похідної")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)

plt.show();

# %% [markdown]
# **Висновок:**
# - f(x)  є лінійною і зростає з часом. Це говорить про те, що чим більше часу ми навчаємось, тим краща оцінка
# - f'(x) завжди має однакове значення (2,22) це говорить про те, що приріст оцінки за кожну годину однаковий і не залежить від того скільки ви вже навчилися
# - отже можемо зробити висновок, що кіл-ть годин витрачених на навчання позитивно впливають на оцінку, але з часом цей тем уповільнюється

# %% [markdown]
# 2. Використовуючи Python і `SymPy`, обчисліть похідні для функцій $ f(x) = \sin(x) $ та $ f(x) = \ln(x) $. Зобразіть ці функції та їхні похідні за допомогою `matplotlib`.

# %%
# Визначаємо символічну змінну
x = sp.symbols('x')

# Визначаємо функцій
f_sin = sp.sin(x)
f_ln = sp.log(x)

# Визначаємо похідні функцій
df_sin = sp.diff(f_sin, x)
df_ln = sp.diff(f_ln, x)

print("Похідна функції 𝑓(𝑥)=sin(𝑥):", df_sin)
print("Похідна функції 𝑓(𝑥)=ln(𝑥):", df_ln)
# Out:
# Похідна функції 𝑓(𝑥)=sin(𝑥): cos(x)
# Похідна функції 𝑓(𝑥)=ln(𝑥): 1/x

# %%
x_val = np.linspace(1, 20, 50)

out_x_val_sin = [] # функція 𝑓(𝑥)=sin(𝑥)
for i in range(len(x_val)): 
    out_x_val_sin.append(math.sin(x_val[i])) 
    i += 1


out_x_val_cos = [] # Похідна функції 𝑓(𝑥)=sin(𝑥): cos(x)
for i in range(len(x_val)): 
    out_x_val_cos.append(math.cos(x_val[i])) 
    i += 1


out_x_val_ln = [np.log(x) for x in x_val] # функція 𝑓(𝑥)=ln(𝑥)

out_x_val=1 / x_val


# Створення графіку
plt.figure(figsize=(15, 5))
plt.plot(x_val, out_x_val_sin, label='f(x)=sin(x)', color='blue')
plt.plot(x_val, out_x_val_cos, label="f'(x)=cos(x)", color='blue', linestyle='dashed')
plt.plot(x_val, out_x_val_ln, label="f(x)=log(x)", color='orange')
plt.plot(x_val, out_x_val, label="f'(x)=1/x", color='orange', linestyle='dashed')

# Додавання легенди, міток та заголовка
plt.title("Графік функції та її похідної")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)

plt.show();

# %% [markdown]
# 3. Загальні витрати компанії від обсягу виробництва задані функцією $ f(x) = x^2 - 5x + 1 $, де $ x $ — кількість вироблених одиниць. Обчисліть похідну цієї функції з допомогою SymPy та візуалізуйте значення функції і її похідної на відрізку від 0 до 100.

# %%
# Визначаємо символічну змінну
x = sp.symbols('x')

f = x ** 2 - 5 * x + 1 # Функція 𝑓(𝑥)=𝑥2−5𝑥+1
d_f = sp.diff(f, x) # похідна функції 𝑓(𝑥)=𝑥2−5𝑥+1

print("Похідна квадратичної функції x^2 + 5x + 1:", d_f)
# Out:
# Похідна квадратичної функції x^2 + 5x + 1: 2*x - 5

# %%
x = np.linspace(0, 100, 10)

f = x ** 2 - 5 * x + 1 # Функція 𝑓(𝑥)=𝑥2−5𝑥+1
d_f = 2 * x - 5 # похідна функції 𝑓(𝑥)=𝑥2−5𝑥+1


# Створення графіку
plt.figure(figsize=(15, 5))
plt.plot(x, f, label='𝑓(x)=x^2−5x+1', color='blue')
plt.plot(x, d_f, label="f'(x)=2x - 5", color='blue', linestyle='dashed')


# Додавання легенди, міток та заголовка
plt.title("Графік функції та її похідної")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)

plt.show();
# Out:
# C:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 119891 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 119891 missing from current font.
#   font.set_text(s, 0, flags=flags)
